# %% [markdown]
# ### Bài thực hành: Phân tích cú pháp
#
#
# Sử dụng thư viện NLTK để minh hoạ phân tích cú pháp văn phạm cấu trúc
#
# 1)	Phân tích văn phạm cho một câu và hiển thị kết quả
#     * Thực hiện phân tích câu "Mary saw Bob" với văn phạm đã cho.
#     * Hiển thị: In ra kết quả dưới dạng cây và sử dụng phương thức pretty_print() để hiển thị cấu trúc cây trực quan.
#
# 2)	Phân tích tính nhập nhằng cấu trúc
#     * Phân tích câu: "the bear chased the squirrel on the tree".
#     * Hãy cho biết có bao nhiêu cây cú pháp được tạo ra?
#
# 3)	Văn phạm phi ngữ cảnh xác suất (PCFG)
#     * Tính xác suất cho câu "big cats and dogs"
#     * Dùng ChartParser liệt kê tất cả các cây cú pháp khả thi.
#     * Dùng ViterbiParser để tìm cây có xác suất cao nhất.

# %% [markdown]
# #### 1) Phân tích văn phạm cho một câu và hiển thị kết quả

# %%
import nltk

# %%
# Khởi tạo văn phạm CFG
grammar1 = nltk.CFG.fromstring("""
  S -> NP VP
  VP -> V NP | V NP PP
  PP -> P NP
  V -> "saw" | "ate" | "walked"
  NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
  Det -> "a" | "an" | "the" | "my"
  N -> "man" | "dog" | "cat" | "telescope" | "park"
  P -> "in" | "on" | "by" | "with"
  """)

# %%
# Tạo trình phân tích cú pháp sử dụng văn phạm ở trên
parser = # ENTER YOUR CODE HERE
print(parser.grammar())
# Out:
# Grammar with 25 productions (start state = S)
#     S -> NP VP
#     VP -> V NP
#     VP -> V NP PP
#     PP -> P NP
#     V -> 'saw'
#     V -> 'ate'
#     V -> 'walked'
#     NP -> 'John'
#     NP -> 'Mary'
#     NP -> 'Bob'
#     NP -> Det N
#     NP -> Det N PP
#     Det -> 'a'
#     Det -> 'an'
#     Det -> 'the'
#     Det -> 'my'
#     N -> 'man'
#     N -> 'dog'
#     N -> 'cat'
#     N -> 'telescope'
#     N -> 'park'
#     P -> 'in'
#     P -> 'on'
#     P -> 'by'
#     P -> 'with'

# %%
# Phân tích cú pháp cho câu 'Mary saw Bob'
# ENTER YOUR CODE HERE
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))
#       S
#   ____|___
#  |        VP
#  |     ___|___
#  NP   V       NP
#  |    |       |
# Mary saw     Bob

# %% [markdown]
# #### 2) Phân tích tính nhập nhằng cấu trúc

# %%
# Khởi tạo văn phạm đệ qui
grammar2 = nltk.CFG.fromstring("""
  S  -> NP VP
  NP -> Det Nom | PropN | NP PP
  Nom -> Adj Nom | N
  VP -> V Adj | V NP | V S | V NP PP
  PP -> P NP
  PropN -> 'Buster' | 'Chatterer' | 'Joe'
  Det -> 'the' | 'a'
  N -> 'bear' | 'squirrel' | 'tree' | 'fish' | 'log'
  Adj  -> 'angry' | 'frightened' |  'little' | 'tall'
  V ->  'chased'  | 'saw' | 'said' | 'thought' | 'was' | 'put'
  P -> 'on'
  """)

# %%
# Phân tích cú pháp cho câu 'the bear chased the squirrel on the tree'
# ENTER YOUR CODE HERE
# Out:
# (S
#   (NP (Det the) (Nom (N bear)))
#   (VP
#     (V chased)
#     (NP (Det the) (Nom (N squirrel)))
#     (PP (P on) (NP (Det the) (Nom (N tree))))))
#                      S
#       _______________|_________
#      |                         VP
#      |          _______________|__________
#      |         |         |                PP
#      |         |         |             ___|___
#      NP        |         NP           |       NP
#   ___|___      |      ___|_____       |    ___|___
#  |      Nom    |     |        Nom     |   |      Nom
#  |       |     |     |         |      |   |       |
# Det      N     V    Det        N      P  Det      N
#  |       |     |     |         |      |   |       |
# the     bear chased the     squirrel  on the     tree
#
# (S
#   (NP (Det the) (Nom (N bear)))
#   (VP
#     (V chased)
#     (NP
#       (NP (Det the) (Nom (N squirrel)))
#       (PP (P on) (NP (Det the) (Nom (N tree)))))))
#                      S
#       _______________|_________
# ...

# %% [markdown]
# #### 3) Văn phạm phi ngữ cảnh xác suất (PCFG)

# %%
# xây dựng văn phạm
grammar = nltk.PCFG.fromstring('''
  NP  -> NNS [0.5] | JJ NNS [0.3] | NP CC NP [0.2]
  NNS -> "cats" [0.1] | "dogs" [0.2] | "mice" [0.3] | NNS CC NNS [0.4]
  JJ  -> "big" [0.4] | "small" [0.6]
  CC  -> "and" [0.9] | "or" [0.1]
  ''')

# %%
# Phân tích cú pháp cho câu 'big cats and dogs' với ViterbiParser
# ENTER YOUR CODE HERE
# Out:
# (NP (JJ big) (NNS (NNS cats) (CC and) (NNS dogs))) (p=0.000864)
#           NP
#   ________|___
#  |           NNS
#  |    ________|___
#  JJ NNS       CC NNS
#  |   |        |   |
# big cats     and dogs

# %%
# Phân tích cú pháp cho câu 'big cats and dogs' với ChartParser
# ENTER YOUR CODE HERE
# Out:
# (NP (JJ big) (NNS (NNS cats) (CC and) (NNS dogs)))
#           NP
#   ________|___
#  |           NNS
#  |    ________|___
#  JJ NNS       CC NNS
#  |   |        |   |
# big cats     and dogs
#
# (NP (NP (JJ big) (NNS cats)) (CC and) (NP (NNS dogs)))
#          NP
#       ___|________
#      NP       |   NP
#   ___|___     |   |
#  JJ     NNS   CC NNS
#  |       |    |   |
# big     cats and dogs
