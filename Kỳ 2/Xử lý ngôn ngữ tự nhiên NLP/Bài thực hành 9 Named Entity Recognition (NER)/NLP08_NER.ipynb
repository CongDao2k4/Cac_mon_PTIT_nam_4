# %% [markdown]
# # Nhận dạng thực thể có tên sử dụng sklearn-crfsuite
#
# Trong notebook này, chúng ta huấn luyện mô hình CRF cơ bản cho nhận dạng thực thể có tên trên dữ liệu CoNLL2002 và kiểm tra trọng số của mô hình để xem mô hình học được những gì.
#
# Chúng ta cần các thư viện Python NLTK> 3.x và sklearn-crfsuite, sử dụng Python 3.

# %%
# !pip install sklearn_crfsuite
# Out:
# Collecting sklearn_crfsuite
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting python-crfsuite>=0.9.7 (from sklearn_crfsuite)
#   Downloading python_crfsuite-0.9.12-cp313-cp313-win_amd64.whl.metadata (4.4 kB)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\asus\anaconda3\lib\site-packages (from sklearn_crfsuite) (1.7.2)
# Requirement already satisfied: tabulate>=0.4.2 in c:\users\asus\anaconda3\lib\site-packages (from sklearn_crfsuite) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from sklearn_crfsuite) (4.67.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sklearn_crfsuite) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sklearn_crfsuite) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sklearn_crfsuite) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sklearn_crfsuite) (3.5.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm>=2.0->sklearn_crfsuite) (0.4.6)
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp313-cp313-win_amd64.whl (303 kB)
# Installing collected packages: python-crfsuite, sklearn_crfsuite
#
#    ---------------------------------------- 2/2 [sklearn_crfsuite]
#
# Successfully installed python-crfsuite-0.9.12 sklearn_crfsuite-0.5.0

# %%
import nltk
import sklearn_crfsuite
import numpy as np
nltk.download('conll2002')
# Out:
# [nltk_data] Downloading package conll2002 to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2002.zip.
# True

# %% [markdown]
# # 1. Dữ liệu huấn luyện (Training data)
#
# Bộ dữ liệu CoNLL 2002 chứa danh sách các câu tiếng Tây Ban Nha, với các thực thể có tên được chú giải. Bộ dữ liệu này sử dụng mã hóa IOB2. Dữ liệu CoNLL 2002 cũng cung cấp các thẻ POS.

# %%
train_sents = list(nltk.corpus.conll2002.iob_sents('esp.train'))
test_sents = list(nltk.corpus.conll2002.iob_sents('esp.testb'))
train_sents[0]
# Out:
# [('Melbourne', 'NP', 'B-LOC'),
#  ('(', 'Fpa', 'O'),
#  ('Australia', 'NP', 'B-LOC'),
#  (')', 'Fpt', 'O'),
#  (',', 'Fc', 'O'),
#  ('25', 'Z', 'O'),
#  ('may', 'NC', 'O'),
#  ('(', 'Fpa', 'O'),
#  ('EFE', 'NC', 'B-ORG'),
#  (')', 'Fpt', 'O'),
#  ('.', 'Fp', 'O')]

# %% [markdown]
# # 2. Trích xuất đặc trưng
#
# Thẻ POS có thể được xem như là các đặc trưng được trích xuất trước. Hãy trích xuất các đặc trưng khác (word parts, thẻ từ loại đã rút gọn - simplified POS tags, lower/title/upper flags, đặc trưng của các từ lân cận - features of nearby words) và chuyển đổi chúng sang định dạng sklear-crfsuite - mỗi một câu phải được chuyển đổi thành một danh sách của từ điển. Đây là một đường cơ sở rất đơn giản; bạn chắc chắn có thể làm tốt hơn.

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        # TODO: Thêm các đặc trưng word shape (viết hoa, số, ...)
        # TODO: Thêm đặc trưng word substrings (hậu tố 2-3 ký tự)
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'postag': postag,
    }
    # Ngữ cảnh từ phía trước (-1)
    if i > 0:
        # TODO: Trích xuất đặc trưng của từ đứng trước (word.lower, postag, ...)
        pass
    else:
        features['BOS'] = True # Beginning of Sentence

    # Ngữ cảnh từ phía sau (+1)
    if i < len(sent)-1:
        # TODO: Trích xuất đặc trưng của từ đứng sau
        pass
    else:
        features['EOS'] = True # End of Sentence

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %% [markdown]
# Các đặc trưng được trích xuất từ một token duy nhất có dạng như sau:

# %%
X_train[0][1]
# Out:
# {'bias': 1.0,
#  'word.lower()': '(',
#  'word[-3:]': '(',
#  'word.isupper()': False,
#  'word.istitle()': False,
#  'word.isdigit()': False,
#  'postag': 'Fpa',
#  'postag[:2]': 'Fp',
#  '-1:word.lower()': 'melbourne',
#  '-1:word.istitle()': True,
#  '-1:word.isupper()': False,
#  '-1:postag': 'NP',
#  '-1:postag[:2]': 'NP',
#  '+1:word.lower()': 'australia',
#  '+1:word.istitle()': True,
#  '+1:word.isupper()': False,
#  '+1:postag': 'NP',
#  '+1:postag[:2]': 'NP'}

# %% [markdown]
# # 3. Huấn luyện mô hình CRF
#
# Khi chúng ta có các đặc trưng ở định dạng phù hợp chúng ta có thể huấn luyện mô hình CRF chuỗi tuyến tính (Trường điều kiện ngẫu nhiên - CRFs) bằng cách sử dụng sklearn_crfsuite.CRF:

# %%
# TODO: Khởi tạo mô hình CRF với các tham số c1, c2, max_iterations và all_possible_transitions = False
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    # TODO: Thêm các tham số
)

# TODO: Huấn luyện mô hình trên tập X_train, y_train
crf.fit(...)

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-LOC', 'B-ORG', 'B-PER', 'I-PER', 'B-MISC', 'I-ORG', 'I-LOC', 'I-MISC']

# %%
y_pred = # TODO: Dự đoán nhãn trên tập X_test

# %%
from sklearn.metrics import classification_report

# %%
gold=[]
for _ in y_test:
    gold+=_
pred=[]
for _ in y_pred:
    pred+=_
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(classification_report(
    gold, pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#        B-LOC      0.796     0.780     0.788      1084
#        I-LOC      0.687     0.622     0.653       325
#       B-MISC      0.710     0.569     0.632       339
#       I-MISC      0.685     0.594     0.637       557
#        B-ORG      0.799     0.843     0.820      1400
#        I-ORG      0.828     0.805     0.816      1104
#        B-PER      0.885     0.868     0.876       735
#        I-PER      0.915     0.929     0.922       634
#
#    micro avg      0.808     0.788     0.798      6178
#    macro avg      0.788     0.751     0.768      6178
# weighted avg      0.805     0.788     0.795      6178

# %% [markdown]
# # 4. Kiểm tra trọng số mô hình
#
# Các mô hình CRF của CRFsuite sử dụng hai loại đặc trưng: đặc trưng trạng thái và đặc trưng chuyển tiếp. Hãy kiểm tra trọng số của chúng:

# %%
import pandas as pd

# %%
for trans, weight in crf.transition_features_.items():
    print(f"Transition: {trans}, Weight: {weight}")
# Out:
# Transition: ('B-LOC', 'B-LOC'), Weight: 0.604672
# Transition: ('B-LOC', 'O'), Weight: -0.30079
# Transition: ('B-LOC', 'B-PER'), Weight: -0.226743
# Transition: ('B-LOC', 'I-LOC'), Weight: 9.552027
# Transition: ('O', 'B-LOC'), Weight: 3.675905
# Transition: ('O', 'O'), Weight: 5.059954
# Transition: ('O', 'B-ORG'), Weight: 5.850349
# Transition: ('O', 'B-PER'), Weight: 4.031904
# Transition: ('O', 'B-MISC'), Weight: 4.66006
# Transition: ('B-ORG', 'B-LOC'), Weight: 0.635639
# Transition: ('B-ORG', 'O'), Weight: -0.125475
# Transition: ('B-ORG', 'B-ORG'), Weight: -1.668179
# Transition: ('B-ORG', 'B-PER'), Weight: -0.295286
# Transition: ('B-ORG', 'B-MISC'), Weight: -2.26201
# Transition: ('B-ORG', 'I-ORG'), Weight: 9.090699
# Transition: ('B-PER', 'B-LOC'), Weight: -0.778107
# Transition: ('B-PER', 'O'), Weight: -0.103723
# Transition: ('B-PER', 'B-ORG'), Weight: -0.982599
# Transition: ('B-PER', 'B-PER'), Weight: -2.803074
# Transition: ('B-PER', 'I-PER'), Weight: 11.194026
# Transition: ('I-PER', 'B-LOC'), Weight: -0.609085
# Transition: ('I-PER', 'O'), Weight: -1.283047
# Transition: ('I-PER', 'B-PER'), Weight: -2.201352
# Transition: ('I-PER', 'I-PER'), Weight: 7.771799
# Transition: ('B-MISC', 'B-LOC'), Weight: -2.068572
# Transition: ('B-MISC', 'O'), Weight: -1.130722
# Transition: ('B-MISC', 'B-ORG'), Weight: -0.125216
# Transition: ('B-MISC', 'B-PER'), Weight: -2.104527
# Transition: ('B-MISC', 'I-MISC'), Weight: 8.658278
# Transition: ('I-ORG', 'B-LOC'), Weight: -2.553301
# Transition: ('I-ORG', 'O'), Weight: -0.365947
# Transition: ('I-ORG', 'B-ORG'), Weight: -1.751767
# Transition: ('I-ORG', 'B-PER'), Weight: 0.201736
# Transition: ('I-ORG', 'B-MISC'), Weight: -2.383614
# Transition: ('I-ORG', 'I-ORG'), Weight: 9.526659
# Transition: ('I-LOC', 'B-LOC'), Weight: -3.074556
# Transition: ('I-LOC', 'O'), Weight: -0.69395
# Transition: ('I-LOC', 'I-LOC'), Weight: 8.37189
# Transition: ('I-MISC', 'B-LOC'), Weight: -3.301188
# Transition: ('I-MISC', 'O'), Weight: -1.179783
# Transition: ('I-MISC', 'B-ORG'), Weight: -2.275223
# Transition: ('I-MISC', 'B-PER'), Weight: -1.053123
# Transition: ('I-MISC', 'B-MISC'), Weight: -1.492927
# Transition: ('I-MISC', 'I-MISC'), Weight: 9.305806

# %%
crf.transition_features_[ ('B-ORG', 'I-ORG')]
# Out:
# 9.090699

# %%
def gettransition_features(crf, targets=None):
    d = crf.transition_features_

    # Tạo danh sách các nhãn hàng và cột từ các cặp nhãn
    if targets is None:
        row_names = list(set(row_name for row_name, _ in d))
        column_names = list(set(column_name for _, column_name in d))
    else:
        row_names = targets
        column_names = targets

    # Khởi tạo DataFrame với các hàng và cột là nhãn thực thể
    df = pd.DataFrame(columns=column_names, index=row_names)

    # Gán giá trị cho từng cặp (row_name, column_name) nếu tồn tại
    for row_name in row_names:
        for column_name in column_names:
            df.loc[row_name, column_name] = d.get((row_name, column_name), 0)

    return df
def getstate_features(crf,top=30,targets=None):
    d=crf.state_features_
    row_names = list(set(row_name for row_name,_ in d))
    column_names = list(set(column_name for _,column_name in d))
    df=pd.DataFrame(columns=column_names,index=row_names)
    for (row_name,column_name), score in d.items():
        df.at[row_name,column_name]=score
    if targets is None:
        targets=column_names
    dfres=pd.DataFrame(columns=targets,index=[i for i in range(top)])
    for col in targets:
        df1=df[col].dropna()
        for i,(x,y) in enumerate(df1.sort_values(ascending=False)[:top].items()):
            dfres[col][i]=str(x)+' '+str(y)
    return dfres

# %%
getstate_features(crf)
# Out:
# <ipython-input-13-b25e4daea4e4>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dfres[col][i]=str(x)+' '+str(y)
#                                I-MISC                                I-LOC  \
# 0        -1:word.lower():1.9 4.149524               word[-3:]:ace 3.461003
# 1        -1:word.lower():xix 2.704681       -1:word.lower():santa 3.008073
# 2      -1:word.lower():danza 2.571277    -1:word.lower():raimundo 2.986746
# 3      -1:word.lower():'2006 2.448304     -1:word.lower():estación 2.96041
# 4       -1:word.lower():ibex 2.272037               word[-3:]:ies 2.905572
# 5       -1:word.lower():2000 2.175932               word[-3:]:rón 2.871379
# 6        -1:word.lower():ftse 2.06672       -1:word.lower():plaza 2.349266
# 7    -1:word.lower():carlos. 2.066233       -1:word.lower():calle 2.322952
# 8     -1:word.lower():rifeña 2.059188     -1:word.lower():avenida 2.269136
# 9       +1:word.lower():ojos 2.049892         word.lower():concha 2.224636
# 10   -1:word.lower():nowhere 2.043721      +1:word.lower():concha 2.211324
# 11             word[-3:]:'92 2.009343               word[-3:]:ama 2.207071
# 12          word.lower():'92 2.009343               word[-3:]:ell 2.141728
# 13         -1:word.istitle() 1.978054               word[-3:]:món 2.126732
# 14  -1:word.lower():ciencias 1.952362   -1:word.lower():fernández 2.080949
# 15     -1:word.lower():viejo 1.951818      -1:word.lower():ciudad 2.074741
# 16   word.lower():habladores 1.950188       -1:word.lower():pilar 2.055015
# 17     +1:word.lower():07,20 1.922609     -1:word.lower():carcedo 2.043793
# 18    -1:word.lower():around 1.921568               word[-3:]:OJA 2.040848
# 19       word.lower():páramo 1.912289      -1:word.lower():puente 2.036426
# 20             word[-3:]:ca. 1.907595        word.lower():navarra 2.028616
# 21    -1:word.lower():aletta 1.903253    -1:word.lower():convento 2.003139
# 22      +1:word.lower():uefa 1.902176      -1:word.lower():fátima 1.995938
# 23    -1:word.lower():obrera 1.867611      +1:word.lower():velles 1.968886
# 24    +1:word.lower():obrera 1.852126      -1:word.lower():africa 1.963492
# 25      +1:word.lower():07,30 1.84042     -1:word.lower():centro. 1.956395
# 26      -1:word.lower():expo 1.824991               word[-3:]:neo 1.955749
# 27      -1:word.lower():prix 1.824879        -1:word.lower():país 1.955449
# 28     word.lower():minusval 1.824781    +1:word.lower():asunción 1.931598
# 29     +1:word.lower():pacto 1.820642  -1:word.lower():monasterio 1.913156
#
#                                     I-ORG  \
# 0              -1:word.lower():l 5.090958
# 1         -1:word.lower():antena 3.304613
# 2          -1:word.lower():amigos 3.09781
# 3        -1:word.lower():hermano 2.920639
# 4          -1:word.lower():grupo 2.558718
# 5        -1:word.lower():defensa 2.456202
# 6       -1:word.lower():inlandes 2.450113
# 7      -1:word.lower():fundación 2.368467
# 8          word.lower():gazzetta 2.340312
# 9       -1:word.lower():mercosur 2.320518
# 10       word.lower():democracia 2.261798
# 11             -1:word.istitle() 2.226473
# 12            word.lower():mixto 2.165772
# 13                 word[-3:]:xto 2.087317
# 14     +1:word.lower():cantabria 2.076605
# 15                 word[-3:]:ics 2.056581
# 16         -1:word.lower():unión 2.055616
# 17        -1:word.lower():papeles 2.04217
# 18        -1:word.lower():sports 2.040246
# 19          -1:word.lower():soir 1.987398
# 20      -1:word.lower():embajada 1.977513
# 21       +1:word.lower():hermano 1.966134
# 22  -1:word.lower():ayuntamiento 1.946222
# 23  -1:word.lower():departamento 1.944769
# 24         -1:word.lower():radio 1.902383
# 25         word.lower():agrarias 1.867724
# 26      word.lower():benedictina 1.857446
# 27       -1:word.lower():consejo 1.851848
# 28            -1:word.lower():de 1.841553
# 29       -1:word.lower():partido 1.833438
#
#                                       B-ORG  \
# 0       word.lower():efe-cantabria 8.293056
# 1   word.lower():psoe-progresistas 7.390282
# 2                    word[-3:]:com 4.997147
# 3                 word.lower():ciu 4.787053
# 4                    word[-3:]:CiU 4.682253
# 5                    word[-3:]:RNO 4.379385
# 6                    word[-3:]:t-e 4.198762
# 7             word.lower():first-e 4.198762
# 8             word.lower():movilgo 4.166614
# 9                    word[-3:]:lGo 4.166614
# 10                   word[-3:]:o-e 4.133645
# 11              word.lower():uno-e 4.133645
# 12         word.lower():continente 4.082324
# 13         word.lower():telefónica 3.974654
# 14               word.lower():ongs 3.912621
# 15                   word[-3:]:NGs 3.912621
# 16              word.lower():xfera 3.838927
# 17              word.lower():terra 3.703578
# 18       -1:word.lower():británica 3.669799
# 19                   word[-3:]:Efe 3.669607
# 20           word.lower():esquerra 3.583892
# 21             word.lower():tigres 3.562275
# 22         word.lower():eurovestir 3.546341
# 23           word.lower():aceralia 3.464934
# 24              word.lower():adega 3.425125
# 25          word.lower():gobiernos 3.362851
# 26            word.lower():cajalón 3.237879
# 27          word.lower():sogecable 3.222465
# 28              word.lower():fenil 3.158075
# 29                word.lower():061 3.129587
#
#                                   B-MISC                               B-LOC  \
# 0                  word[-3:]:com 6.04648  -1:word.lower():cantabria 4.535354
# 1         word.lower():diversia 4.368867       word.lower():estrecho 4.13434
# 2       word.lower():diversia.com 4.2209        word.lower():murcia 3.887435
# 3      word.lower():competencia 4.059248      word.lower():asunción 3.868612
# 4          word.lower():justicia 3.64606             word.istitle() 3.661413
# 5          word.lower():sanidad 3.639206     -1:word.lower():nuboso 3.596845
# 6         word.lower():atlantis 3.265039        word.lower():retiro 3.398475
# 7              word.lower():ave 3.264959          word.lower():asia 3.386719
# 8                 word[-3:]:AVE 3.264959        word.lower():teruel 3.303542
# 9          word.lower():primaria 3.21744              word[-3:]:AÑA 3.083375
# 10      word.lower():exteriores 3.208879              word[-3:]:AEL 3.071624
# 11  word.lower():expovacaciones 3.143982          word.lower():peru 3.070505
# 12             word.lower():opas 3.09029              word[-3:]:ERU 3.070505
# 13         word.lower():derecho 3.075633          word.lower():pinto 3.06163
# 14         word.lower():alcosto 3.028596       word.lower():galicia 3.034733
# 15       word.lower():educación 3.001821           word.lower():rfa 2.938171
# 16     word.lower():agricultura 2.999173              word[-3:]:RFA 2.938171
# 17            word.lower():giro 2.920271        word.lower():líbano 2.912643
# 18        +1:word.lower():turín 2.915135  -1:word.lower():despejado 2.909456
# 19         word.lower():deporte 2.851845      word.lower():estación 2.866754
# 20          word.lower():hanson 2.845634        word.lower():asmara 2.834952
# 21    word.lower():constitución 2.839895       word.lower():vitoria 2.826282
# 22         word.lower():guernica 2.75257       word.lower():balcanes 2.75507
# 23        word.lower():internet 2.605518        word.lower():parque 2.742664
# 24              word.lower():ops 2.59503      word.lower():belgrado 2.737227
# 25                 word[-3:]:OPS 2.59503   +1:word.lower():corrales 2.711094
# 26       +1:word.lower():lisboa 2.583264       word.lower():miranda 2.691851
# 27                word[-3:]:IFE 2.572399       word.lower():almería 2.659501
# 28             word.lower():ope 2.569549              word[-3:]:jea 2.582307
# 29                word[-3:]:OPE 2.569549          word.lower():ejea 2.582307
#
#                                  I-PER                            B-PER  \
# 0     +1:word.lower():gándara 3.075519    word.lower():valedor 4.096726
# 1        word.lower():gándara 3.050119   -1:word.lower():según 3.923477
# 2       -1:word.lower():maría 2.991262      word.lower():monti 3.907752
# 3               word[-3:]:rdt 2.957829  word.lower():cañizares 3.773785
# 4          -1:word.lower():v. 2.862446           word[-3:]:vic 3.658213
# 5               word[-3:]:llo 2.678636   word.lower():quaranta 3.652343
# 6         word.lower():swardt 2.582116      word.lower():pujol 3.357388
# 7           -1:word.istitle() 2.568776  word.lower():mcmanaman 3.356988
# 8               word[-3:]:ano 2.315125           word[-3:]:ini 3.348331
# 9      -1:word.lower():infanta 2.28357    -1:word.lower():dijo 3.238913
# 10              word[-3:]:ita 2.193325    word.lower():machito 3.110153
# 11        word.lower():bosque 2.160979       word.lower():papa 3.086824
# 12     +1:word.lower():señaló 2.117364     word.lower():ismael 3.058001
# 13       -1:word.lower():juan 2.086991     -1:word.lower():efe 3.040248
# 14  -1:word.lower():francisco 2.075698     word.lower():silvia 3.004775
# 15    -1:word.lower():abogado 2.073375  word.lower():morientes 2.933044
# 16    +1:word.lower():borgoña 2.065265       word.lower():raul 2.932464
# 17       word.lower():borgoña 2.039192       word.lower():bonet 2.92826
# 18      -1:word.lower():duque 2.038007        word.lower():mas 2.909129
# 19              word[-3:]:xon 2.031981      word.lower():salva 2.901116
# 20  +1:word.lower():rigoberta 2.030876     word.lower():dorado 2.895566
# 21     -1:word.lower():carlos 2.024074    word.lower():murillo 2.861435
# 22         +1:word.lower():c. 2.022452    word.lower():angloma 2.847836
# 23              word[-3:]:món 2.017732    word.lower():zambrano 2.81422
# 24    -1:word.lower():segundo 1.965224   word.lower():príncipe 2.810468
# 25              word[-3:]:lez 1.877039  word.lower():cervantes 2.799091
# 26          -1:word.lower():j. 1.85466   word.lower():guterres 2.797155
# 27      -1:word.lower():lluís 1.834673    word.lower():romario 2.707211
# 28              word[-3:]:ini 1.833403    word.lower():clinton 2.705996
# 29              word[-3:]:dez 1.833328   word.lower():cardenal 2.701012
#
#                                        O
# 0                word.lower():a 5.244113
# 1                word.lower():y 4.472483
# 2                 postag[:2]:Fp 4.412342
# 3           -1:word.lower():día 4.384134
# 4                  word[-3:]:La 3.989929
# 5              word.lower():r/p 3.709767
# 6                 word[-3:]:R/P 3.709767
# 7         word.lower():acciones 3.640881
# 8                           BOS 3.596312
# 9             -1:word.isupper() 3.316431
# 10              word.lower():euro 3.2436
# 11                word[-3:]:NTE 3.220572
# 12                  word[-3:]:Y 3.160519
# 13           word.lower():metro 3.020874
# 14                         bias 3.020521
# 15                 word[-3:]:En 3.005206
# 16                 word[-3:]:El 2.991462
# 17            word.lower():mayo 2.980304
# 18        +1:word.lower():etapa 2.950666
# 19        -1:word.lower():otras 2.944438
# 20                 word[-3:]:lub 2.91679
# 21      word.lower():ciudadanos 2.835032
# 22                 word[-3:]:ble 2.82853
# 23         +1:word.lower():museo 2.82086
# 24          word.lower():cambio 2.776576
# 25                word[-3:]:Día 2.765051
# 26             word.lower():may 2.750843
# 27  -1:word.lower():agricultura 2.740888
# 28          word.lower():semana 2.729578
# 29           -1:word.lower():23 2.704202

# %%
gettransition_features(crf)
# Out:
#            I-ORG     I-LOC      I-PER    I-MISC     B-PER     B-ORG    B-MISC  \
# I-ORG   9.526659      None       None      None  0.201736 -1.751767 -2.383614
# I-LOC       None   8.37189       None      None      None      None      None
# I-PER       None      None   7.771799      None -2.201352      None      None
# I-MISC      None      None       None  9.305806 -1.053123 -2.275223 -1.492927
# B-PER       None      None  11.194026      None -2.803074 -0.982599      None
# B-ORG   9.090699      None       None      None -0.295286 -1.668179  -2.26201
# B-MISC      None      None       None  8.658278 -2.104527 -0.125216      None
# B-LOC       None  9.552027       None      None -0.226743      None      None
# O           None      None       None      None  4.031904  5.850349   4.66006
#
#            B-LOC         O
# I-ORG  -2.553301 -0.365947
# I-LOC  -3.074556  -0.69395
# I-PER  -0.609085 -1.283047
# I-MISC -3.301188 -1.179783
# B-PER  -0.778107 -0.103723
# B-ORG   0.635639 -0.125475
# B-MISC -2.068572 -1.130722
# B-LOC   0.604672  -0.30079
# O       3.675905  5.059954

# %%
import matplotlib.pyplot as plt
def showmatrix(df):
    matrix=df.values.tolist()
    plt.figure(figsize=(10,10))
    plt.imshow(df.values.tolist(), cmap='Blues')
    plt.xticks(range(len(df.columns)), df.columns)
    plt.yticks(range(len(df.index)), df.index)
    for i in range(len(matrix[0])):
        for j in range(len(matrix)):
            c = matrix[j][i]
            if not np.isnan(c):
                plt.text(i, j, f'{c:.2f}', va='center', ha='center')
    plt.colorbar()
    plt.show()

# %%
showmatrix(gettransition_features(crf))

# %% [markdown]
# Các đặc trưng chuyển tiếp có ý nghĩa: ít nhất mô hình đã học rằng I-ENTITY phải theo sau B-ENTITY. Nó cũng học được rằng một số chuyển tiếp khó xảy ra, ví dụ: ngay sau tên tổ chức thường không phải là một vị trí (I-ORG -> B-LOC có trọng số âm lớn).
#
# Các đặc trưng không sử dụng từ điển địa lý, vì vậy mô hình phải nhớ một số tên địa lý từ dữ liệu huấn luyện, ví dụ: España là một địa điểm.
#
# Nếu chúng ta regularize CRF hơn, chúng ta có thể kỳ vọng rằng các đặc trưng duy nhất mang tính tổng quát sẽ vẫn còn, và thẻ ghi nhớ sẽ mất đi. Với hệ số chính quy L1 (tham số c1) của hầu hết các đặc trưng sẽ được chuyển về không. Hãy kiểm tra xem việc regularization có ảnh hưởng gì đến trọng số CRF:

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=20,
    c2=0.1,
    max_iterations=50,
    all_possible_transitions=False,
)
crf.fit(X_train, y_train);

# %%
getstate_features(crf)
# Out:
# <ipython-input-13-b25e4daea4e4>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dfres[col][i]=str(x)+' '+str(y)
#                              I-MISC                           I-LOC  \
# 0        -1:word.istitle() 1.378629    -1:word.lower():san 1.340597
# 1       -1:word.lower():de 0.745535     -1:word.lower():de 0.787007
# 2         word.lower():2000 0.72016           word[-3:]:de 0.659985
# 3     -1:word.lower():copa 0.484818        word.lower():de 0.641261
# 4             +1:postag:Fe 0.462633      -1:word.istitle() 0.550075
# 5         +1:postag[:2]:Fe 0.462633          word[-3:]:sco 0.524662
# 6        +1:word.lower():" 0.462633     -1:word.lower():la 0.355831
# 7     -1:word.lower():plan 0.449131   -1:word.lower():país 0.346608
# 8     -1:word.lower():liga 0.413435              postag:SP 0.257754
# 9         -1:postag[:2]:VM 0.378719          postag[:2]:SP 0.257754
# 10          word.isdigit() 0.342227         word.istitle() 0.245209
# 11        -1:postag[:2]:SP 0.327551       -1:postag[:2]:DA 0.231239
# 12            -1:postag:SP 0.327551           -1:postag:DA 0.231239
# 13           word[-3:]:000 0.291825          word[-3:]:del 0.217928
# 14            word[-3:]:de 0.255215       +1:postag[:2]:Fp 0.177782
# 15           word[-3:]:nes 0.231204       word.lower():del 0.177317
# 16         word.lower():de 0.212835  -1:word.lower():nueva 0.128418
# 17            -1:postag:NC 0.206494     +1:word.lower():de 0.127978
# 18        -1:postag[:2]:NC 0.206494      +1:word.istitle() 0.111232
# 19             +1:postag:Z 0.192775       -1:postag[:2]:SP 0.108944
# 20         +1:postag[:2]:Z 0.192775           -1:postag:SP 0.108944
# 21           postag[:2]:SP 0.169195              postag:DA 0.065391
# 22               postag:SP 0.169195          postag[:2]:DA 0.065391
# 23      +1:word.lower():de 0.166465           -1:postag:AQ 0.060434
# 24            word[-3:]:el 0.147105       -1:postag[:2]:AQ 0.060434
# 25  word.lower():campeones 0.132019           +1:postag:Fc 0.048559
# 26            word[-3:]:en 0.127383       +1:postag[:2]:Fc 0.048559
# 27      -1:word.lower():en 0.124626      +1:word.lower():, 0.048559
# 28        -1:postag[:2]:AQ 0.103926          word[-3:]:iro 0.044716
# 29            -1:postag:AQ 0.103926     word.lower():vasco 0.034416
#
#                                 I-ORG                               B-ORG  \
# 0          -1:word.istitle() 1.672377             word.isupper() 2.842833
# 1         -1:word.lower():de 1.258784           word.lower():efe 2.321646
# 2              word[-3:]:rid 0.921057    word.lower():telefónica 1.622493
# 3              word[-3:]:dos 0.767563           word.lower():ciu 1.618155
# 4               word[-3:]:de 0.637423              word[-3:]:CiU 1.521246
# 5            word.lower():de 0.610083             word.istitle() 1.508823
# 6    -1:word.lower():consejo 0.550808              word[-3:]:EFE 1.484718
# 7        word.lower():madrid 0.509069       word.lower():gobierno 1.27687
# 8                -1:postag:SP 0.48098        word.lower():estado 1.233946
# 9            -1:postag[:2]:SP 0.48098         -1:word.lower():al 1.127552
# 10      -1:word.lower():real 0.416574  word.lower():ayuntamiento 0.781311
# 11              word[-3:]:la 0.395334              word[-3:]:rno 0.757051
# 12                word[-3:]:ara 0.331              word[-3:]:ión 0.733523
# 13          +1:word.lower():" 0.30676       word.lower():estados 0.715277
# 14           +1:postag[:2]:Fe 0.30676                   postag:VMI 0.6662
# 15               +1:postag:Fe 0.30676           word.lower():junta 0.6644
# 16        word.lower():unidos 0.26934              word[-3:]:nta 0.538152
# 17             word[-3:]:del 0.265837              postag[:2]:Fe 0.485928
# 18         +1:word.lower():( 0.260147                  postag:Fe 0.485928
# 19             +1:postag:Fpa 0.260147             word.lower():" 0.485928
# 20          word.lower():del 0.255759                word[-3:]:" 0.485928
# 21    -1:word.lower():estados 0.24643      word.lower():ejército 0.482767
# 22          -1:postag[:2]:DA 0.243548              postag[:2]:NP 0.449415
# 23              -1:postag:DA 0.243548                  postag:NP 0.449415
# 24             word.isupper() 0.23542         -1:word.lower():el 0.431716
# 25             postag[:2]:AQ 0.234806         word.lower():china 0.428549
# 26                 postag:AQ 0.234806                        BOS 0.427319
# 27              postag[:2]:NC 0.20732           -1:postag[:2]:DA 0.426091
# 28                  postag:NC 0.20732               -1:postag:DA 0.426091
# 29  -1:word.lower():comisión 0.185274          -1:word.istitle() 0.399428
#
#                             B-MISC                         B-LOC  \
# 0          word.isupper() 1.761318       word.istitle() 2.945774
# 1        word.lower():ley 1.216061   -1:word.lower():en 2.123728
# 2   word.lower():internet 1.200286    -1:word.isupper() 1.631877
# 3       word.lower():copa 1.040957  word.lower():madrid 1.048765
# 4        word.lower():liga 0.98534        word[-3:]:rid 1.046487
# 5           word[-3:]:iga 0.980953        word[-3:]:ona 1.036417
# 6           word[-3:]:net 0.906059   word.lower():parís 0.931975
# 7            postag[:2]:Z 0.802807        word[-3:]:eva 0.909552
# 8                postag:Z 0.802807       word.isupper() 0.862926
# 9   word.lower():interior 0.779268        word[-3:]:rís 0.840903
# 10         word.istitle() 0.740927  word.lower():líbano 0.793678
# 11          word[-3:]:ior 0.736476        word[-3:]:EUU 0.711673
# 12          postag[:2]:Fe 0.665829    word.lower():eeuu 0.711673
# 13              postag:Fe 0.665829  word.lower():españa 0.703726
# 14         word.lower():" 0.665829        word[-3:]:lla 0.684056
# 15            word[-3:]:" 0.665829        word[-3:]:ida 0.624541
# 16          word[-3:]:opa 0.521213     +1:postag[:2]:Fp 0.610093
# 17    word.lower():juegos 0.512896        postag[:2]:VM 0.600394
# 18      word.lower():plan 0.492284        word[-3:]:rra 0.530843
# 19          word[-3:]:lan 0.488332     -1:postag[:2]:Fp 0.467667
# 20       -1:postag[:2]:DI 0.333997      word.lower():san 0.40945
# 21           -1:postag:DI 0.333997        word[-3:]:aña 0.404347
# 22           -1:postag:DA 0.322566    -1:word.lower():( 0.403885
# 23       -1:postag[:2]:DA 0.322566        -1:postag:Fpa 0.403885
# 24       -1:postag[:2]:Fe 0.290331        postag[:2]:NC 0.358685
# 25      -1:word.lower():" 0.290331            postag:NC 0.358685
# 26           -1:postag:Fe 0.290331         +1:postag:Fg 0.352864
# 27                    BOS 0.276272    +1:word.lower():- 0.352864
# 28    -1:word.lower():del 0.261159     +1:postag[:2]:Fg 0.352864
# 29            +1:postag:Z 0.248727    +1:word.istitle() 0.349953
#
#                              I-PER                           B-PER  \
# 0       -1:word.istitle() 2.300114  -1:word.lower():según 2.723371
# 1      -1:word.lower():de 0.956045         word.istitle() 1.753907
# 2            word[-3:]:la 0.805501      word.lower():reyes 1.29447
# 3    -1:word.lower():juan 0.650042           -1:postag:VMI 0.82965
# 4          word.istitle() 0.559515             postag:VMI 0.736971
# 5        -1:postag[:2]:SP 0.405523      -1:word.lower():a 0.724233
# 6            -1:postag:SP 0.405523          word[-3:]:uel 0.710222
# 7           -1:postag:VMI 0.373387          +1:postag:VMI 0.633716
# 8         word.lower():la 0.364987       +1:postag[:2]:VM 0.498718
# 9               postag:DA 0.336285          word[-3:]:yes 0.489275
# 10          postag[:2]:DA 0.336285          postag[:2]:NP 0.422422
# 11       -1:postag[:2]:VM 0.313585              postag:NP 0.422422
# 12   -1:word.lower():josé 0.311677       -1:postag[:2]:VM 0.420452
# 13          postag[:2]:NC 0.310624          postag[:2]:VM 0.360788
# 14              postag:NC 0.310624      -1:word.lower():, 0.357317
# 15     -1:word.lower():la 0.305583       -1:postag[:2]:Fc 0.357317
# 16        word.lower():de 0.286748           -1:postag:Fc 0.357317
# 17           word[-3:]:de 0.262925          postag[:2]:NC 0.343217
# 18  -1:word.lower():maría 0.253001              postag:NC 0.343217
# 19           -1:postag:AQ 0.251746      +1:word.istitle() 0.315881
# 20       -1:postag[:2]:AQ 0.251746      +1:word.isupper() 0.306953
# 21      -1:word.isupper() 0.212532              postag:AQ 0.294099
# 22               postag:SP 0.19193          postag[:2]:AQ 0.294099
# 23           postag[:2]:SP 0.19193   -1:word.lower():para 0.220866
# 24   -1:word.lower():luis 0.101646          word[-3:]:osé 0.200683
# 25       -1:postag[:2]:NC 0.094476      word.lower():juan 0.179607
# 26           -1:postag:NC 0.094476      word.lower():josé 0.173644
# 27    -1:word.lower():del 0.090272    -1:word.lower():con 0.161347
# 28       +1:postag[:2]:Fp 0.078304    -1:word.lower():por 0.143586
# 29         word.isupper() 0.072446          word[-3:]:uan 0.104264
#
#                                O
# 0         postag[:2]:Fp 3.894055
# 1     -1:word.isupper() 3.239002
# 2                   BOS 3.230772
# 3        word.lower():a 2.745023
# 4                   bias 2.73034
# 5     -1:word.istitle() 1.896226
# 6          word[-3:]:La 1.841878
# 7                   EOS 1.815917
# 8          word[-3:]:El 1.676831
# 9             postag:CC 1.543494
# 10        postag[:2]:CC 1.543494
# 11       word.lower():y 1.506227
# 12          word[-3:]:A 1.241612
# 13          word[-3:]:, 1.103101
# 14       word.lower():, 1.103101
# 15            postag:Fc 1.103101
# 16        postag[:2]:Fc 1.103101
# 17            postag:RG 1.032047
# 18        postag[:2]:RG 1.032047
# 19        postag[:2]:SP 0.901403
# 20            postag:SP 0.901403
# 21        +1:postag:VMN 0.830433
# 22    +1:word.isupper() 0.803581
# 23            postag:CS 0.743292
# 24        postag[:2]:CS 0.743292
# 25  +1:word.lower():que 0.687206
# 26     +1:postag[:2]:NC 0.603163
# 27         +1:postag:NC 0.603163
# 28          word[-3:]:y 0.487359
# 29         +1:postag:AQ 0.480225

# %%
showmatrix(gettransition_features(crf))

# %% [markdown]
# Như chúng ta có thể thấy, các thẻ được ghi nhớ hầu hết đã biến mất và mô hình hiện dựa vào khuôn dạng từ (word shapes) và nhãn từ loại (POS tags). Chỉ còn lại một số đặc trưng khác không. Trong ví dụ này, sự thay đổi có thể khiến chất lượng kém hơn, nhưng đó là một vấn đề riêng.
#
# Hãy tập trung vào trọng số chuyển tiếp. Chúng ta có thể cho rằng các chuyển tiếp O -> I-ENTIRY có trọng số âm lớn vì chúng là không thể. Nhưng những chuyển tiếp này có trọng số bằng không, không có trọng số âm, cả trong mô hình được chính quy hóa nhiều và trong mô hình ban đầu. Có gì đó đang xảy ra ở đây.
#
# Lý do chúng bằng 0 là crfsuite đã không nhìn thấy những chuyển đổi này trong dữ liệu huấn luyện và để tiết kiệm thời gian tính toán nên đã cho rằng không cần phải học trọng số đối với chúng. Đây là mặc định, nhưng có thể tắt nó bằng cách sử dụng sklearn_crfsuite.CRF tùy chọn all_possible_transitions. Hãy kiểm tra xem nó ảnh hưởng như thế nào đến kết quả:

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=20,
    all_possible_transitions=True,
)
crf.fit(X_train, y_train);

# %%
showmatrix(gettransition_features(crf))

# %% [markdown]
# Với all_possible_transitions = True CRF đã học được các trọng số âm lớn cho các chuyển đổi không thể như O -> I-ORG.

# %% [markdown]
# # 5. Tùy chỉnh
# Bảng trên lớn và khó quan sát, ta sẽ sử dụng một số tùy chọn để chỉ xem xét một phần của các đặc trưng. Chúng ta có thể chỉ kiểm tra một tập hợp con các nhãn:

# %%
getstate_features(crf,top=10, targets=['O', 'B-ORG', 'I-ORG'])
# Out:
# <ipython-input-22-efbfffa987e3>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dfres[col][i]=str(x)+' '+str(y)
#                         O                           B-ORG  \
# 0            BOS 4.931176         word.isupper() 3.040547
# 1  postag[:2]:Fp 3.754403       word.lower():efe 2.952151
# 2           bias 3.538947          word[-3:]:EFE 1.850966
# 3   postag[:2]:Fc 2.32761  word.lower():gobierno 1.278428
# 4  word.lower():, 2.32761          word[-3:]:rno 1.033159
# 5     word[-3:]:, 2.32761         word.istitle() 1.005305
# 6       postag:Fc 2.32761    -1:word.lower():del 0.863561
# 7      postag:CC 2.140987          postag[:2]:NC 0.716049
# 8  postag[:2]:CC 2.140987              postag:NC 0.716049
# 9            EOS 1.927981        word.lower():pp 0.694327
#
#                            I-ORG
# 0    -1:word.lower():de 1.158985
# 1     -1:word.istitle() 0.992838
# 2          -1:postag:SP 0.636564
# 3      -1:postag[:2]:SP 0.636564
# 4  -1:word.lower():real 0.569994
# 5        word.istitle() 0.547423
# 6      +1:postag[:2]:Fe 0.459033
# 7     +1:word.lower():" 0.459033
# 8          +1:postag:Fe 0.459033
# 9         word[-3:]:rid 0.456152

# %%
showmatrix(gettransition_features(crf, targets=['O', 'B-ORG', 'I-ORG']))
