# %% [markdown]
# Naive Bayes
# - BC 1: tIsnh xác xut tiên nghiệm
# P(spam) = số tài liệu spam/ tổng số tài liệu
# P(ham) = số tài liệu ham / tổng số tài liệu
#
# - BC 2: tính xác suất khả năng P(x|y)
